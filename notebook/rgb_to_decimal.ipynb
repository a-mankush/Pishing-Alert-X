# %%
cd ..

# %%
import colorgram
import pandas as pd

from color_code import GetRGBValues
from url_screenshot import GetScreenshots, PathConfig

df = pd.read_csv("notebook/data/dataset_B_05_2020.csv").head()


class Helpers:
    @staticmethod
    def RGBtoDecimal(rgb) -> int:
        return int("%02x%02x%02x" % (rgb.r, rgb.g, rgb.b), 16)


def getColors(n, i):
    colors = colorgram.extract("Screenshots/url.png", n)
    print(colors)
    return Helpers.RGBtoDecimal(colors[i].rgb)


def get_deci(url, save_screenshot=True):
    ss = GetScreenshots()
    try:
        ss.get_screenshots(url, save_screenshot=True)
        decimal_code = getColors(3, 0)
    except Exception as e:
        print(f"The {url} is not available. The iloc us")
        decimal_code = 0
    return decimal_code


df["color_1"] = df["url"].apply(lambda x: get_deci(x))
# data['color_1'] = data['hash'].apply(lambda x: getColors(x, 3, 0))
# Out:
# [<colorgram.py Color: Rgb(r=255, g=255, b=255), 100.0%>]
# [<colorgram.py Color: Rgb(r=255, g=255, b=255), 100.0%>]
# The https://support-appleld.com.secureupdate.duilawyeryork.com/ap/89e6a3b4b063b8d/?cmd=_update&dispatch=89e6a3b4b063b8d1b&locale=_ is not available. The iloc us
# [<colorgram.py Color: Rgb(r=36, g=94, b=146), 41.598067734589925%>, <colorgram.py Color: Rgb(r=251, g=251, b=250), 36.232872204599005%>, <colorgram.py Color: Rgb(r=165, g=150, b=133), 22.169060060811077%>]
# [<colorgram.py Color: Rgb(r=18, g=22, b=29), 71.90663690320159%>, <colorgram.py Color: Rgb(r=0, g=0, b=0), 24.4537769524456%>, <colorgram.py Color: Rgb(r=22, g=44, b=32), 3.6395861443528057%>]

# %%
print(df[["url", "color_1"]])
# Out:
#                                                  url   color_1
# 0              http://www.crestonwood.com/router.php  16777215
# 1  http://shadetreetechnology.com/V4/validation/a...  16777215
# 2  https://support-appleld.com.secureupdate.duila...         0
# 3                                 http://rgipt.ac.in   2383506
# 4  http://www.iracing.com/tracks/gateway-motorspo...   1185309

# %%
# OHE status
df = pd.get_dummies(data=df, columns=['status'], drop_first=True)

# %%
df
# Out:
#                                                  url  length_url  \
# 0              http://www.crestonwood.com/router.php          37
# 1  http://shadetreetechnology.com/V4/validation/a...          77
# 2  https://support-appleld.com.secureupdate.duila...         126
# 3                                 http://rgipt.ac.in          18
# 4  http://www.iracing.com/tracks/gateway-motorspo...          55
#
#    length_hostname  ip  nb_dots  nb_hyphens  nb_at  nb_qm  nb_and  nb_or  ...  \
# 0               19   0        3           0      0      0       0      0  ...
# 1               23   1        1           0      0      0       0      0  ...
# 2               50   1        4           1      0      1       2      0  ...
# 3               11   0        2           0      0      0       0      0  ...
# 4               15   0        2           2      0      0       0      0  ...
#
#    domain_with_copyright  whois_registered_domain  domain_registration_length  \
# 0                      1                        0                          45
# 1                      0                        0                          77
# 2                      0                        0                          14
# 3                      0                        0                          62
# 4                      1                        0                         224
#
#    domain_age  web_traffic  dns_record  google_index  page_rank   color_1  \
# 0          -1            0           1             1          4  16777215
# 1        5767            0           0             1          2  16777215
# 2        4004      5828815           0             1          0         0
# 3          -1       107721           0             0          3   2383506
# 4        8175         8725           0             0          6   1185309
#
#    status_phishing
# 0            False
# 1             True
# 2             True
# 3            False
# 4            False
#
# [5 rows x 90 columns]

# %%
import matplotlib.pyplot as plt

# %%
# Plot correlation
corr = df.drop(columns='url').corr()['status_phishing']
corr.plot(kind='bar', figsize=(16, 8))


plt.axhline(y=0.3, color='red')
plt.axhline(y=-0.3, color='red')


plt.show()

# %%
import seaborn as sns

# %%
c = df.drop(columns='url').corr()

# %%
plt.figure(figsize=(15, 15))
sns.heatmap(c)
# Out:
# <Axes: >

# %%
# Out:
# c:\Users\aman kushwaha\Desktop\The\ML Project\Pishing Alert X
# c:\Users\aman kushwaha\Desktop\The\ML Project\Pishing Alert X\venv\Lib\site-packages\IPython\core\magics\osm.py:417: UserWarning: using dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]
